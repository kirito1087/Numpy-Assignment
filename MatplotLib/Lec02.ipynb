# %%
! pip3 install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/nikunj/Introduction to Machine Learning/pandas/.venv/lib/python3.14/site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in /Users/nikunj/Introduction to Machine Learning/pandas/.venv/lib/python3.14/site-packages (from scikit-learn) (2.5.2)
# Requirement already satisfied: scipy>=1.10.0 in /Users/nikunj/Introduction to Machine Learning/pandas/.venv/lib/python3.14/site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in /Users/nikunj/Introduction to Machine Learning/pandas/.venv/lib/python3.14/site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in /Users/nikunj/Introduction to Machine Learning/pandas/.venv/lib/python3.14/site-packages (from scikit-learn) (2.25.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /Users/nikunj/Introduction to Machine Learning/pandas/.venv/lib/python3.14/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in /Users/nikunj/Introduction to Machine Learning/pandas/.venv/lib/python3.14/site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
df = pd.read_csv("../Assignment/Titanic.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
# Drop unusable columns, fill age, drop 2 rows
df = df.drop(columns = ['Cabin', 'Name', 'Ticket', 'PassengerId'])

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df.dropna(subset='Embarked')
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  28.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [889 rows x 8 columns]
