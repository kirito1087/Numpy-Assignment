# %%
x = "Hello World!"
print(x.upper())
print(x.lower())
print(x.capitalize())
print(x)
# Out:
# HELLO WORLD!
# hello world!
# Hello world!
# Hello World!

# %%
print(x.title())
# Out:
# Hello World!

# %%
print(x.strip()) #left and right me string ke space remove kr deta hai
# Out:
# Hello World!

# %%
x = "****### Hello World***#####"
print(x.strip("#*"))
# Out:
#  Hello World

# %%
x = "123-123-123-456"
print(x.replace("-", ""))
# Out:
# 123123123456

# %%
x = "welcome.to,vedam,for,learning.machine.learning,"
x=x.replace(".","*")
x=x.replace(",",".")
x=x.replace("*",",")

print(x)
# Out:
# welcome,to.vedam.for.learning,machine,learning.

# %%
x="welcome#to vedam for#   learning machine#learning"
print(x.strip("#"))
# Out:
# welcome#to vedam for#   learning machine#learning

# %%
secret_code = "charlie-bravo-alpha"
x = secret_code
lst = x.split("-")
lst = lst[::-1]
lst = [i.upper() for i in lst]
ans = " ".join(lst)
print(ans)
# Out:
# ALPHA BRAVO CHARLIE
